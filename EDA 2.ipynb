# %%
import pandas as pd
import numpy as np

# %%
import os
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_rows", 150)
pd.set_option("display.max_columns", 150)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("players_19.csv/players_19.csv")
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     193080  https://sofifa.com/player/193080/david-de-gea-...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# 2             Neymar        Neymar da Silva Santos Júnior   26  1992-02-05
# 3             De Gea                David De Gea Quintana   27  1990-11-07
# 4       K. De Bruyne                      Kevin De Bruyne   27  1991-06-28
#
#    height_cm  weight_kg nationality            club_name  \
# 0        187         83    Portugal             Juventus
# ...

# %%
df.shape
# Out:
# (18085, 106)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18085 entries, 0 to 18084
# Columns: 106 entries, sofifa_id to rb
# dtypes: float64(17), int64(45), object(44)
# memory usage: 14.6+ MB

# %%
df.isna().sum()
# Out:
# sofifa_id                         0
# player_url                        0
# short_name                        0
# long_name                         0
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# nationality                       0
# club_name                       234
# league_name                     234
# league_rank                     234
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# real_face                         0
# release_clause_eur             1259
# player_tags                   16556
# ...

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)

# %%
# heatmap 
f, ax = plt.subplots(figsize=(25, 15))
sns.heatmap(df.corr(), annot=True, linewidths=0.9, linecolor="red", fmt='.1f', ax=ax)
plt.show()

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
plt.subplots(figsize=(25, 15))
wordcloud = WordCloud(background_color='white', width=1920, height=1080).generate(" ".join(df.nationality))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('stylish_country_name.png')
plt.show()

# %%
df.club_name.head()
# Out:
# 0               Juventus
# 1           FC Barcelona
# 2    Paris Saint-Germain
# 3      Manchester United
# 4        Manchester City
# Name: club_name, dtype: object

# %%
df['club_name'].fillna("No Club", inplace=True)

# %%
df['club_name'].isna().sum()
# Out:
# 0

# %%
df['league_name'].head()
# Out:
# 0           Italian Serie A
# 1    Spain Primera Division
# 2            French Ligue 1
# 3    English Premier League
# 4    English Premier League
# Name: league_name, dtype: object

# %%
df['league_name'].fillna("No League", inplace=True)

# %%
df['league_name'].isna().sum()
# Out:
# 0

# %%
df['league_rank'].unique()
# Out:
# array([ 1.,  2., nan,  3.,  4.])

# %%
idx = 0
for j in df.isna().sum():
    if j > 0:
        print(df.columns[idx], " => ", j)
        col = df.columns[idx]
#         print(df[col].dtype)
    idx += 1
# Out:
# league_rank  =>  234
# release_clause_eur  =>  1259
# player_tags  =>  16556
# team_position  =>  234
# team_jersey_number  =>  234
# loaned_from  =>  17069
# joined  =>  1250
# contract_valid_until  =>  234
# nation_position  =>  16981
# nation_jersey_number  =>  16981
# pace  =>  2029
# shooting  =>  2029
# passing  =>  2029
# dribbling  =>  2029
# defending  =>  2029
# physic  =>  2029
# gk_diving  =>  16056
# gk_handling  =>  16056
# gk_kicking  =>  16056
# gk_reflexes  =>  16056
# gk_speed  =>  16056
# gk_positioning  =>  16056
# player_traits  =>  10083

# %%
df.player_tags.dtype
# Out:
# dtype('O')

# %%
idx = 0
for j in df.isna().sum():
    if j > 0:
        print(df.columns[idx], " => ", j)
        col = df.columns[idx]
#         print(df[col])
    idx += 1
# Out:
# player_tags  =>  16556
# team_position  =>  234
# loaned_from  =>  17066
# joined  =>  1250
# nation_position  =>  16981
# player_traits  =>  10083

# %%
idx=0

for i in df.isna().sum():
    if i > 0:
        col = df.columns[idx]
        if df[col].dtype == "float":
#             print(df[col].mode())
            df[col].fillna(df[col].mean(), inplace=True)
        else:
            print("not done")
#         elif df[col].dtype == "object":
#             df[col].fillna(df[col].median(), inplace=True)
        
    idx+=1
# Out:
# not done
# not done
# not done
# not done
# not done
# not done

# %%
df['shooting'].dtype
# Out:
# dtype('float64')

# %%
type(df.league_rank.dtype)
# Out:
# numpy.dtype[float64]

# %%
df.player_tags.mode()
# Out:
# 0    #Strength
# dtype: object

# %%
df.isna().sum().plot(kind='bar', figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %%
# player_tags  =>  16556
# team_position  =>  234
# loaned_from  =>  17066
# joined  =>  1250
# nation_position  =>  16981
# player_traits  =>  10083

new_df = df[['player_tags', 'team_position', 'loaned_from', 'joined', 'nation_position', 'player_traits']]

# %%
new_df.head()
# Out:
#                                          player_tags team_position  \
# 0  #Speedster, #Dribbler, #Distance Shooter, #Acr...            ST
# 1  #Dribbler, #Distance Shooter, #FK Specialist, ...            RW
# 2  #Speedster, #Dribbler, #FK Specialist, #Acroba...            LW
# 3                                                NaN            GK
# 4  #Dribbler, #Playmaker, #Engine, #Distance Shoo...           RCM
#
#   loaned_from      joined nation_position  \
# 0    Atalanta  2018-07-10              LS
# 1  SL Benfica  2004-07-01              CF
# 2    Sassuolo  2017-08-03              LW
# 3         NaN  2011-07-01              GK
# 4         NaN  2015-08-30             RCM
#
#                                        player_traits
# 0  Power Free-Kick, Diver, Flair, Long Shot Taker...
# 1  Finesse Shot, Long Shot Taker (AI), Speed Drib...
# 2  Diver, Selfish, Flair, Speed Dribbler (AI), Te...
# 3                     GK Long Throw, Saves with Feet
# ...

# %%
new_df.player_tags.isna().sum()
# Out:
# 16556

# %%
df.shape
# Out:
# (18085, 106)

# %%
new_df.player_tags.unique()
# Out:
# array(['#Speedster, #Dribbler, #Distance Shooter, #Acrobat, #Clinical Finisher, #Complete Forward',
#        '#Dribbler, #Distance Shooter, #FK Specialist, #Acrobat, #Clinical Finisher',
#        '#Speedster, #Dribbler, #FK Specialist, #Acrobat, #Clinical Finisher, #Complete Forward',
#        nan,
#        '#Dribbler, #Playmaker, #Engine, #Distance Shooter, #Crosser, #Complete Midfielder',
#        '#Aerial Threat, #Tackling, #Tactician, #Complete Defender',
#        '#Dribbler, #Clinical Finisher',
#        '#Dribbler, #Playmaker, #Engine, #Crosser, #Acrobat, #Complete Midfielder',
#        '#Speedster, #Dribbler, #Acrobat',
#        '#Aerial Threat, #Tackling, #Tactician, #Strength, #Complete Defender',
#        '#Playmaker, #Distance Shooter, #Crosser, #Complete Midfielder',
#        '#FK Specialist, #Clinical Finisher',
#        '#Dribbler, #Playmaker, #FK Specialist, #Acrobat, #Complete Midfielder',
#        '#Dribbler, #Playmaker', '#Engine, #Clinical Finisher',
# ...

# %%
new_df['player_tags'].fillna("#Speedster, #Dribbler, #Distance Shooter, #Acrobat, #Clinical Finisher, #Complete Forward", inplace=True)

# %%
new_df['player_tags'][0].replace("#", '').split(',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12244/1808543031.py in <module>
# ----> 1 new_df['player_tags'].replace("#", '').split(',')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
new_df['player_tags'] = new_df['player_tags'].apply(lambda x: x.replace('#', ''))

# %%
new_df['player_tags'].head()
# Out:
# 0    Speedster, Dribbler, Distance Shooter, Acrobat...
# 1    Dribbler, Distance Shooter, FK Specialist, Acr...
# 2    Speedster, Dribbler, FK Specialist, Acrobat, C...
# 3    Speedster, Dribbler, Distance Shooter, Acrobat...
# 4    Dribbler, Playmaker, Engine, Distance Shooter,...
# Name: player_tags, dtype: object

# %%
df['player_tags'][df['short_name'] == "De Gea"]
# Out:
# 3    NaN
# Name: player_tags, dtype: object

# %%
df['short_name'].head()
# Out:
# 0    Cristiano Ronaldo
# 1             L. Messi
# 2               Neymar
# 3               De Gea
# 4         K. De Bruyne
# Name: short_name, dtype: object

# %%
df['player_tags'].isna().sum()
# Out:
# 0

# %%
new_df.head()
# Out:
#                                          player_tags team_position  \
# 0  #Speedster, #Dribbler, #Distance Shooter, #Acr...            ST
# 1  #Dribbler, #Distance Shooter, #FK Specialist, ...            RW
# 2  #Speedster, #Dribbler, #FK Specialist, #Acroba...            LW
# 3  #Speedster, #Dribbler, #Distance Shooter, #Acr...            GK
# 4  #Dribbler, #Playmaker, #Engine, #Distance Shoo...           RCM
#
#   loaned_from      joined nation_position  \
# 0    Atalanta  2018-07-10              LS
# 1  SL Benfica  2004-07-01              CF
# 2    Sassuolo  2017-08-03              LW
# 3         NaN  2011-07-01              GK
# 4         NaN  2015-08-30             RCM
#
#                                        player_traits player_tags_list
# 0  Power Free-Kick, Diver, Flair, Long Shot Taker...         Tackling
# 1  Finesse Shot, Long Shot Taker (AI), Speed Drib...         Tackling
# 2  Diver, Selfish, Flair, Speed Dribbler (AI), Te...         Tackling
# ...

# %%
new_df.drop('player_tags_list', axis=1, inplace=True)

# %%
new_df.head()
# Out:
#                                          player_tags team_position  \
# 0  Speedster, Dribbler, Distance Shooter, Acrobat...            ST
# 1  Dribbler, Distance Shooter, FK Specialist, Acr...            RW
# 2  Speedster, Dribbler, FK Specialist, Acrobat, C...            LW
# 3  Speedster, Dribbler, Distance Shooter, Acrobat...            GK
# 4  Dribbler, Playmaker, Engine, Distance Shooter,...           RCM
#
#   loaned_from      joined nation_position  \
# 0    Atalanta  2018-07-10              LS
# 1  SL Benfica  2004-07-01              CF
# 2    Sassuolo  2017-08-03              LW
# 3         NaN  2011-07-01              GK
# 4         NaN  2015-08-30             RCM
#
#                                        player_traits
# 0  Power Free-Kick, Diver, Flair, Long Shot Taker...
# 1  Finesse Shot, Long Shot Taker (AI), Speed Drib...
# 2  Diver, Selfish, Flair, Speed Dribbler (AI), Te...
# 3                     GK Long Throw, Saves with Feet
# ...

# %%
for i in new_df['player_tags'].head():
    print(len(i.split(',')))
# Out:
# 6
# 5
# 6
# 6
# 6

# %%
new_df['player_tags_count'] = new_df['player_tags'].apply(lambda x: len(x.split(',')))

# %%
new_df.head()
# Out:
#                                          player_tags team_position  \
# 0  Speedster, Dribbler, Distance Shooter, Acrobat...            ST
# 1  Dribbler, Distance Shooter, FK Specialist, Acr...            RW
# 2  Speedster, Dribbler, FK Specialist, Acrobat, C...            LW
# 3  Speedster, Dribbler, Distance Shooter, Acrobat...            GK
# 4  Dribbler, Playmaker, Engine, Distance Shooter,...           RCM
#
#   loaned_from      joined nation_position  \
# 0    Atalanta  2018-07-10              LS
# 1  SL Benfica  2004-07-01              CF
# 2    Sassuolo  2017-08-03              LW
# 3         NaN  2011-07-01              GK
# 4         NaN  2015-08-30             RCM
#
#                                        player_traits  player_tags_count
# 0  Power Free-Kick, Diver, Flair, Long Shot Taker...                  6
# 1  Finesse Shot, Long Shot Taker (AI), Speed Drib...                  5
# 2  Diver, Selfish, Flair, Speed Dribbler (AI), Te...                  6
# ...

# %%
df['team_position'].head()
# Out:
# 0     ST
# 1     RW
# 2     LW
# 3     GK
# 4    RCM
# Name: team_position, dtype: object

# %%
df['team_position'].isna().sum()
# Out:
# 234

# %%
df['team_position'].mode()
# Out:
# 0    SUB
# dtype: object

# %%
df['team_position'].fillna('SUB', inplace=True)

# %%
df['team_position'].isna().sum()
# Out:
# 0

# %%
df['team_position'].unique()
# Out:
# array(['ST', 'RW', 'LW', 'GK', 'RCM', 'LCB', 'SUB', 'LCM', 'CAM', 'LS',
#        'RM', 'CDM', 'LB', 'RCB', 'CM', 'RB', 'CB', 'LDM', 'LM', 'RS',
#        'RDM', 'LF', 'CF', 'RES', 'LAM', 'RAM', 'RF', 'LWB', 'RWB'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
new_df['team_position'] = lb.fit_transform(new_df['team_position'])

# %%
new_df.head()
# Out:
#                                          player_tags  team_position  \
# 0  Speedster, Dribbler, Distance Shooter, Acrobat...             27
# 1  Dribbler, Distance Shooter, FK Specialist, Acr...             25
# 2  Speedster, Dribbler, FK Specialist, Acrobat, C...             14
# 3  Speedster, Dribbler, Distance Shooter, Acrobat...              5
# 4  Dribbler, Playmaker, Engine, Distance Shooter,...             19
#
#   loaned_from      joined nation_position  \
# 0    Atalanta  2018-07-10              LS
# 1  SL Benfica  2004-07-01              CF
# 2    Sassuolo  2017-08-03              LW
# 3         NaN  2011-07-01              GK
# 4         NaN  2015-08-30             RCM
#
#                                        player_traits  player_tags_count
# 0  Power Free-Kick, Diver, Flair, Long Shot Taker...                  6
# 1  Finesse Shot, Long Shot Taker (AI), Speed Drib...                  5
# 2  Diver, Selfish, Flair, Speed Dribbler (AI), Te...                  6
# ...

# %%
new_df.drop("player_tags", axis=1, inplace=True)

# %%
new_df.head()
# Out:
#    team_position loaned_from      joined nation_position  \
# 0             27    Atalanta  2018-07-10              LS
# 1             25  SL Benfica  2004-07-01              CF
# 2             14    Sassuolo  2017-08-03              LW
# 3              5         NaN  2011-07-01              GK
# 4             19         NaN  2015-08-30             RCM
#
#                                        player_traits  player_tags_count
# 0  Power Free-Kick, Diver, Flair, Long Shot Taker...                  6
# 1  Finesse Shot, Long Shot Taker (AI), Speed Drib...                  5
# 2  Diver, Selfish, Flair, Speed Dribbler (AI), Te...                  6
# 3                     GK Long Throw, Saves with Feet                  6
# 4  Leadership, Early Crosser, Long Passer (AI), L...                  6

# %%
pd.concat((df, new_df), axis=1).head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
#
#    height_cm  weight_kg nationality     club_name             league_name  \
# 0        187         83    Portugal      Juventus         Italian Serie A
# 1        170         72   Argentina  FC Barcelona  Spain Primera Division
#
#    league_rank  overall  potential  value_eur  wage_eur player_positions  \
# 0          1.0       94         94   77000000    400000           ST, LW
# 1          1.0       94         94  110500000    575000       CF, RW, ST
#
#   preferred_foot  international_reputation  weak_foot  skill_moves  \
# ...

# %%
df['gk_diving'] = df['gk_diving'].apply(lambda x: int(round(x)))

# %%
df['gk_diving'].head()
# Out:
# 0    65
# 1    65
# 2    65
# 3    90
# 4    65
# Name: gk_diving, dtype: int64

# %%
df['player_url'].head()
# Out:
# 0    https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1    https://sofifa.com/player/158023/lionel-messi/...
# 2    https://sofifa.com/player/190871/neymar-da-sil...
# 3    https://sofifa.com/player/193080/david-de-gea-...
# 4    https://sofifa.com/player/192985/kevin-de-bruy...
# Name: player_url, dtype: object

# %%
list(df.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club_name',
#  'league_name',
#  'league_rank',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
# ...
